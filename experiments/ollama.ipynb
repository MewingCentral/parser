# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3")
llm.invoke("Come up with 10 names for a song about parrots")
# Out:
# AIMessage(content='What a colorful topic! Here are 10 potential song title ideas inspired by parrots:\n\n1. **"Flock Together"** - A playful anthem about the social nature of parrots.\n2. **"Rainbow Ruckus"** - A fun, upbeat tune capturing the vibrant colors and lively energy of parrots.\n3. **"Squawk of Joy"** - A feel-good song celebrating the happy sounds parrots make.\n4. **"Polite Parrot"** - A tongue-in-cheek track poking fun at the reputation of parrots being a bit cheeky.\n5. **"Feathered Friends Forever"** - A heartwarming ballad about the special bond between humans and parrots.\n6. **"Polly\'s Pride"** - A song inspired by the iconic parrot name "Polly," with themes of confidence and self-expression.\n7. **"The Rainbow Roster"** - A lively, alliterative title that evokes the colorful diversity of parrots.\n8. **"Tweet Treats"** - A catchy tune about the sweet treats parrots love to snack on.\n9. **"Parrot\'s Perch"** - A song about finding one\'s own place in the world, inspired by the clever antics of parrots on their perches.\n10. **"Fowl Play"** - A playful pun that references both the birds\' reputation for mischief and the idea of having fun.\n\nI hope these ideas inspire your songwriting!', additional_kwargs={}, response_metadata={'model': 'llama3', 'created_at': '2024-10-07T18:00:39.333724046Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 37860877029, 'load_duration': 18882597, 'prompt_eval_count': 22, 'prompt_eval_duration': 98995000, 'eval_count': 310, 'eval_duration': 37700766000}, id='run-5ad69cdf-a4fb-435c-9e1e-f33a146d635c-0', usage_metadata={'input_tokens': 22, 'output_tokens': 310, 'total_tokens': 332})

# %%
llm.invoke("Come up with 10 names for a song about parrots")
# Out:
# AIMessage(content='What a colorful topic! Here are 10 potential song title ideas about parrots:\n\n1. "Flock Together"\n2. "Polynesian Boogie" (a nod to the species\' tropical habitats)\n3. "Parrot\'s Perch"\n4. "Rainbow Rhapsody" (inspired by their vibrant plumage)\n5. "Squawk and Shine"\n6. "Feathered Frenzy"\n7. "Mimic My Heartbeat"\n8. "Plumage of Love" (a play on the phrase "language of love")\n9. "The Parrot\'s Tale" (a storytelling-inspired title)\n10. "Winged Wisdom"\n\nThese song titles aim to capture the playful, vibrant essence of parrots, while also exploring themes of community, beauty, and connection.', additional_kwargs={}, response_metadata={'model': 'llama3', 'created_at': '2024-10-07T18:01:04.306267657Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 21033828981, 'load_duration': 13240963, 'prompt_eval_count': 22, 'prompt_eval_duration': 133931000, 'eval_count': 169, 'eval_duration': 20845072000}, id='run-495e8aea-7631-4009-8a96-acf3ec1fa02e-0', usage_metadata={'input_tokens': 22, 'output_tokens': 169, 'total_tokens': 191})

# %%
from typing import Optional

from pydantic import BaseModel, Field


class Joke(BaseModel):
    """Joke to tell user."""

    setup: str = Field(description="The setup of the joke")
    punchline: str = Field(description="The punchline to the joke")
    rating: Optional[int] = Field(description="How funny the joke is, from 1 to 10")

structured_llm = llm.with_structured_output(Joke)

await structured_llm.invoke("Tell me a joke about cats")
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[9], line 15
#      11     rating: Optional[int] = Field(description="How funny the joke is, from 1 to 10")
#      13 structured_llm = llm.with_structured_output(Joke)
# ---> 15 await structured_llm.invoke("Tell me a joke about cats")
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/langchain_core/runnables/base.py:3020, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3018 context.run(_set_config_context, config)
#    3019 if i == 0:
# -> 3020     input = context.run(step.invoke, input, config, **kwargs)
#    3021 else:
#    3022     input = context.run(step.invoke, input, config)
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/langchain_core/runnables/base.py:5343, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5337 def invoke(
#    5338     self,
#    5339     input: Input,
#    5340     config: Optional[RunnableConfig] = None,
#    5341     **kwargs: Optional[Any],
#    5342 ) -> Output:
# -> 5343     return self.bound.invoke(
#    5344         input,
#    5345         self._merge_configs(config),
#    5346         **{**self.kwargs, **kwargs},
#    5347     )
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
#     290             run_name=config.get("run_name"),
#     291             run_id=config.pop("run_id", None),
#     292             **kwargs,
#     293         ).generations[0][0],
#     294     ).message
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:784, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     776 def generate_prompt(
#     777     self,
#     778     prompts: list[PromptValue],
#    (...)
#     781     **kwargs: Any,
#     782 ) -> LLMResult:
#     783     prompt_messages = [p.to_messages() for p in prompts]
# --> 784     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:641, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     639         if run_managers:
#     640             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 641         raise e
#     642 flattened_outputs = [
#     643     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     644     for res in results
#     645 ]
#     646 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:631, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     628 for i, m in enumerate(messages):
#     629     try:
#     630         results.append(
# --> 631             self._generate_with_cache(
#     632                 m,
#     633                 stop=stop,
#     634                 run_manager=run_managers[i] if run_managers else None,
#     635                 **kwargs,
#     636             )
#     637         )
#     638     except BaseException as e:
#     639         if run_managers:
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:853, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     851 else:
#     852     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 853         result = self._generate(
#     854             messages, stop=stop, run_manager=run_manager, **kwargs
#     855         )
#     856     else:
#     857         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/langchain_ollama/chat_models.py:644, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     637 def _generate(
#     638     self,
#     639     messages: List[BaseMessage],
#    (...)
#     642     **kwargs: Any,
#     643 ) -> ChatResult:
# --> 644     final_chunk = self._chat_stream_with_aggregation(
#     645         messages, stop, run_manager, verbose=self.verbose, **kwargs
#     646     )
#     647     generation_info = final_chunk.generation_info
#     648     chat_generation = ChatGeneration(
#     649         message=AIMessage(
#     650             content=final_chunk.text,
#    (...)
#     654         generation_info=generation_info,
#     655     )
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/langchain_ollama/chat_models.py:545, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     536 def _chat_stream_with_aggregation(
#     537     self,
#     538     messages: List[BaseMessage],
#    (...)
#     542     **kwargs: Any,
#     543 ) -> ChatGenerationChunk:
#     544     final_chunk = None
# --> 545     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     546         if not isinstance(stream_resp, str):
#     547             chunk = ChatGenerationChunk(
#     548                 message=AIMessageChunk(
#     549                     content=(
#    (...)
#     562                 ),
#     563             )
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/langchain_ollama/chat_models.py:517, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     515 params["options"]["stop"] = stop
#     516 if "tools" in kwargs:
# --> 517     yield self._client.chat(
#     518         model=params["model"],
#     519         messages=ollama_messages,
#     520         stream=False,
#     521         options=Options(**params["options"]),
#     522         keep_alive=params["keep_alive"],
#     523         format=params["format"],
#     524         tools=kwargs["tools"],
#     525     )
#     526 else:
#     527     yield from self._client.chat(
#     528         model=params["model"],
#     529         messages=ollama_messages,
#    (...)
#     533         format=params["format"],
#     534     )
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/ollama/_client.py:236, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     233   if images := message.get('images'):
#     234     message['images'] = [_encode_image(image) for image in images]
# --> 236 return self._request_stream(
#     237   'POST',
#     238   '/api/chat',
#     239   json={
#     240     'model': model,
#     241     'messages': messages,
#     242     'tools': tools or [],
#     243     'stream': stream,
#     244     'format': format,
#     245     'options': options or {},
#     246     'keep_alive': keep_alive,
#     247   },
#     248   stream=stream,
#     249 )
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/ollama/_client.py:99, in Client._request_stream(self, stream, *args, **kwargs)
#      93 def _request_stream(
#      94   self,
#      95   *args,
#      96   stream: bool = False,
#      97   **kwargs,
#      98 ) -> Union[Mapping[str, Any], Iterator[Mapping[str, Any]]]:
# ---> 99   return self._stream(*args, **kwargs) if stream else self._request(*args, **kwargs).json()
#
# File ~/.cache/pypoetry/virtualenvs/parser-2Aur3UYS-py3.12/lib/python3.12/site-packages/ollama/_client.py:75, in Client._request(self, method, url, **kwargs)
#      73   response.raise_for_status()
#      74 except httpx.HTTPStatusError as e:
# ---> 75   raise ResponseError(e.response.text, e.response.status_code) from None
#      77 return response
#
# ResponseError: llama3 does not support tools
